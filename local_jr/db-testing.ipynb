# %%
from src.db_class import FinanceDB
import yfinance as yf

# %%
db = FinanceDB('first.db')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Projects/Money-generator/local_jr/src/db_class.py in add_security(self, ticker)
#      71             print(info['symbol'], info['longName'], info['exchange'], info['currency'])
# ---> 72             ticker_attr = ( info['symbol'], info['longName'], info['exchange'], info['currency'] )
#      73             cursor.execute('''INSERT IGNORE INTO security ( ticker, company, exchange, currency ) VALUES (?,?,?,?)''',
#
# OperationalError: near "IGNORE": syntax error
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Projects/Money-generator/local_jr/src/db_class.py in __init__(self, db_filename)
#      55             for ticker in db_tickers:
# ---> 56                 self.add_security(ticker)
#      57                 #add_security_price_daily(ticker)
#
# ~/Projects/Money-generator/local_jr/src/db_class.py in add_security(self, ticker)
#      81             # company info
# ---> 82             company_attr = ( info['longName'], info['sector'], info['industry'], info['country'], info['market'], info['fullTimeEmployees'], info['website'] )
#      83             cursor.execute('''INSERT IGNORE INTO company ( name, sector, industry, country, market, employees, website ) VALUES (?,?,?,?,?,?,?)''',
#
# ~/Projects/Money-generator/local_jr/src/db_class.py in __exit__(self, exc_type, exc_value, traceback)
#      31         if exc_type is not None:
# ---> 32             traceback.print_exception(exc_type, exc_value, traceback)
#      33         return
#
# AttributeError: 'traceback' object has no attribute 'print_exception'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10790/4118898191.py in <module>
# ----> 1 db = FinanceDB('first.db')
#
# ~/Projects/Money-generator/local_jr/src/db_class.py in __init__(self, db_filename)
#      54
#      55             for ticker in db_tickers:
# ---> 56                 self.add_security(ticker)
#      57                 #add_security_price_daily(ticker)
#      58
#
# ~/Projects/Money-generator/local_jr/src/db_class.py in __exit__(self, exc_type, exc_value, traceback)
#      30         self.connection.close()
#      31         if exc_type is not None:
# ---> 32             traceback.print_exception(exc_type, exc_value, traceback)
#      33         return
#      34
#
# AttributeError: 'traceback' object has no attribute 'print_exception'

# %%
data = yf.download("SPY", period='1d', interval='5m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-11-24 09:30:00-05:00  466.059998  466.230011  465.339600  465.945007
# 2021-11-24 09:35:00-05:00  465.940002  466.704987  465.690002  465.778198
# 2021-11-24 09:40:00-05:00  465.774994  465.859985  465.350006  465.630005
# 2021-11-24 09:45:00-05:00  465.619995  466.079987  465.190002  465.510010
# 2021-11-24 09:50:00-05:00  465.500000  465.989990  465.195007  465.559998
# 2021-11-24 09:55:00-05:00  465.570007  466.339996  465.500000  466.260010
# 2021-11-24 10:00:00-05:00  466.250000  467.279999  465.632690  467.059998
# 2021-11-24 10:05:00-05:00  467.070007  467.320007  466.470001  466.510010
# 2021-11-24 10:10:00-05:00  466.505005  466.779999  465.929993  466.529999
# 2021-11-24 10:15:00-05:00  466.529999  466.730011  466.329987  466.519989
# 2021-11-24 10:20:00-05:00  466.540009  467.160004  466.369995  466.970001
# 2021-11-24 10:25:00-05:00  466.970001  467.480011  466.899994  467.339996
